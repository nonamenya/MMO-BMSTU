# %%
# !python3 -m spacy download ru_core_news_sm
# Out:
# Python

# %%
# !pip3 install -U spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.0.6-cp38-cp38-win_amd64.whl (11.9 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\nonam\anaconda4\lib\site-packages (from spacy) (20.9)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.5-cp38-cp38-win_amd64.whl (36 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.5-cp38-cp38-win_amd64.whl (21 kB)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.4-cp38-cp38-win_amd64.whl (6.5 MB)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\nonam\anaconda4\lib\site-packages (from spacy) (1.20.2)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.5.2-py3-none-any.whl (42 kB)
# Collecting typer<0.4.0,>=0.3.0
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.1-cp38-cp38-win_amd64.whl (451 kB)
# Collecting thinc<8.1.0,>=8.0.3
#   Downloading thinc-8.0.5-cp38-cp38-win_amd64.whl (1.0 MB)
# Requirement already satisfied: setuptools in c:\users\nonam\anaconda4\lib\site-packages (from spacy) (52.0.0.post20210125)
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\nonam\anaconda4\lib\site-packages (from spacy) (2.25.1)
# Collecting spacy-legacy<3.1.0,>=3.0.4
#   Downloading spacy_legacy-3.0.6-py2.py3-none-any.whl (12 kB)
# Collecting pydantic<1.8.0,>=1.7.1
#   Downloading pydantic-1.7.4-cp38-cp38-win_amd64.whl (1.8 MB)
# Requirement already satisfied: jinja2 in c:\users\nonam\anaconda4\lib\site-packages (from spacy) (3.0.0)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.5-cp38-cp38-win_amd64.whl (112 kB)
# Collecting catalogue<2.1.0,>=2.0.3
#   Downloading catalogue-2.0.4-py3-none-any.whl (16 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\nonam\anaconda4\lib\site-packages (from spacy) (4.59.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\nonam\anaconda4\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Collecting smart-open<4.0.0,>=2.2.0
#   Downloading smart_open-3.0.0.tar.gz (113 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nonam\anaconda4\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nonam\anaconda4\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\nonam\anaconda4\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\nonam\anaconda4\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Collecting click<7.2.0,>=7.1.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in c:\users\nonam\anaconda4\lib\site-packages (from jinja2->spacy) (2.0.1)
# Building wheels for collected packages: smart-open
#   Building wheel for smart-open (setup.py): started
#   Building wheel for smart-open (setup.py): finished with status 'done'
#   Created wheel for smart-open: filename=smart_open-3.0.0-py3-none-any.whl size=107097 sha256=3c4f245f3364454472f60390b97b56d1f5513a1072f1289aaf1d1bbfc05629d4
#   Stored in directory: c:\users\nonam\appdata\local\pip\cache\wheels\11\73\9a\f91ac1f1816436b16423617c5be5db048697ff152a9c4346f2
# Successfully built smart-open
# Installing collected packages: murmurhash, cymem, click, catalogue, wasabi, typer, srsly, smart-open, pydantic, preshed, blis, thinc, spacy-legacy, pathy, spacy
#   Attempting uninstall: click
#     Found existing installation: click 8.0.1
#     Uninstalling click-8.0.1:
#       Successfully uninstalled click-8.0.1
# Successfully installed blis-0.7.4 catalogue-2.0.4 click-7.1.2 cymem-2.0.5 murmurhash-1.0.5 pathy-0.5.2 preshed-3.0.5 pydantic-1.7.4 smart-open-3.0.0 spacy-3.0.6 spacy-legacy-3.0.6 srsly-2.4.1 thinc-8.0.5 typer-0.3.2 wasabi-0.8.2

# %%
text = 'Отец работает в ФСБ. Сегодня срочно вызвали на совещание. Вернулся поздно и ничего не объяснил. Сказал лишь собирать вещи и бежать в магазин за продуктами на две недели. Сейчас едем куда-то далеко за город. Не знаю что происходит, но мне кажется началось...'

# %%
# !spacy download ru_core_news_sm
# Out:
# Collecting ru-core-news-sm==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.0.0/ru_core_news_sm-3.0.0-py3-none-any.whl (17.9 MB)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in c:\users\nonam\anaconda4\lib\site-packages (from ru-core-news-sm==3.0.0) (3.0.6)
# Collecting pymorphy2>=0.9
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
# Collecting docopt>=0.6
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (3.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (2.4.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (2.0.4)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (0.3.2)
# Requirement already satisfied: setuptools in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (52.0.0.post20210125)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (0.7.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (20.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (0.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (2.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (2.25.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (8.0.5)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (1.20.2)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (1.7.4)
# Requirement already satisfied: jinja2 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (3.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (1.0.5)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (0.5.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (4.59.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in c:\users\nonam\anaconda4\lib\site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (3.0.6)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\nonam\anaconda4\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (2.4.7)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\users\nonam\anaconda4\lib\site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (3.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nonam\anaconda4\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nonam\anaconda4\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\nonam\anaconda4\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\nonam\anaconda4\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (2.10)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\nonam\anaconda4\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in c:\users\nonam\anaconda4\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->ru-core-news-sm==3.0.0) (2.0.1)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=211a55cc8cfac2d5127aabdcb2e96a468755d495472e2fa29275395542d3613a
#   Stored in directory: c:\users\nonam\appdata\local\pip\cache\wheels\56\ea\58\ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built docopt
# Installing collected packages: pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2, ru-core-news-sm
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844 ru-core-news-sm-3.0.0
# [+] Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')

# %%
from spacy.lang.ru import Russian
import spacy
nlp = spacy.load('ru_core_news_sm')
spacy_text = nlp(text)
spacy_text
# Out:
# Отец работает в ФСБ. Сегодня срочно вызвали на совещание. Вернулся поздно и ничего не объяснил. Сказал лишь собирать вещи и бежать в магазин за продуктами на две недели. Сейчас едем куда-то далеко за город. Не знаю что происходит, но мне кажется началось...

# %%
for t in spacy_text:
    print(t)
# Out:
# Отец
# работает
# в
# ФСБ
# .
# Сегодня
# срочно
# вызвали
# на
# совещание
# .
# Вернулся
# поздно
# и
# ничего
# не
# объяснил
# .
# Сказал
# лишь
# собирать
# вещи
# и
# бежать
# в
# магазин
# за
# продуктами
# на
# две
# недели
# .
# Сейчас
# едем
# куда
# -
# то
# далеко
# за
# город
# .
# Не
# знаю
# что
# происходит
# ,
# но
# мне
# кажется
# началось
# ...

# %%
for token in spacy_text:
    print('{} - {} - {}'.format(token.text, token.pos_, token.dep_))
# Out:
# Отец - NOUN - nsubj
# работает - VERB - ROOT
# в - ADP - case
# ФСБ - PROPN - obl
# . - PUNCT - punct
# Сегодня - ADV - advmod
# срочно - ADV - advmod
# вызвали - VERB - ROOT
# на - ADP - case
# совещание - NOUN - obl
# . - PUNCT - punct
# Вернулся - VERB - ROOT
# поздно - ADV - advmod
# и - CCONJ - cc
# ничего - PRON - obj
# не - PART - advmod
# объяснил - VERB - conj
# . - PUNCT - punct
# Сказал - VERB - ROOT
# лишь - PART - advmod
# собирать - VERB - xcomp
# вещи - NOUN - obj
# и - CCONJ - cc
# бежать - VERB - conj
# в - ADP - case
# магазин - NOUN - obl
# за - ADP - case
# продуктами - NOUN - obl
# на - ADP - case
# две - NUM - nummod:gov
# недели - NOUN - nmod
# . - PUNCT - punct
# Сейчас - ADV - advmod
# едем - VERB - ROOT
# куда - ADV - advmod
# - - ADV - advmod
# то - ADV - advmod
# далеко - ADV - advmod
# за - ADP - case
# город - NOUN - obl
# . - PUNCT - punct
# Не - PART - advmod
# знаю - VERB - ROOT
# что - PRON - nsubj
# происходит - VERB - xcomp
# , - PUNCT - punct
# но - CCONJ - cc
# мне - PRON - iobj
# кажется - VERB - conj
# началось - VERB - csubj
# ... - PUNCT - punct

# %%
for token in spacy_text:
      print(token, token.lemma, token.lemma_)
# Out:
# Отец 14450738938621776550 отец
# работает 18093316098418404276 работать
# в 15939375860797385675 в
# ФСБ 1657952533157752304 фсб
# . 12646065887601541794 .
# Сегодня 3743476782037285079 сегодня
# срочно 8096777608835996340 срочно
# вызвали 4148649703802432973 вызвать
# на 16191904166009283104 на
# совещание 17464455287975571083 совещание
# . 12646065887601541794 .
# Вернулся 4941367432331070349 вернуться
# поздно 16524028545803964142 поздно
# и 15015917632809974589 и
# ничего 16656340000673424156 ничто
# не 5319710824202933802 не
# объяснил 2352046934737434013 объяснить
# . 12646065887601541794 .
# Сказал 6152693818835699119 сказать
# лишь 15085157332802532245 лишь
# собирать 14537722008012877099 собирать
# вещи 5257797144122852077 вещь
# и 15015917632809974589 и
# бежать 4083569733797762419 бежать
# в 15939375860797385675 в
# магазин 2540648777317725863 магазин
# за 8493257168786769949 за
# продуктами 3701259051577741515 продукт
# на 16191904166009283104 на
# две 15400399964508618332 два
# недели 4405352024371216385 неделя
# . 12646065887601541794 .
# Сейчас 16232035594175008769 сейчас
# едем 9230081358857171090 ехать
# куда 10102307719012850409 куда
# - 9153284864653046197 -
# то 3313051931268380979 то
# далеко 455673685042458442 далеко
# за 8493257168786769949 за
# город 6063391427805833384 город
# . 12646065887601541794 .
# Не 5319710824202933802 не
# знаю 13740122314186774628 знать
# что 647928276737163203 что
# происходит 14088133631182316283 происходить
# , 2593208677638477497 ,
# но 14653780147686393572 но
# мне 3554529162876815229 мне
# кажется 15632230894970259627 казаться
# началось 6847603908540456777 начаться
# ... 10875615029400813363 ...

# %%
for ent in spacy_text.ents:
    print(ent.text, ent.label_)
# Out:
# ФСБ ORG

# %%
from spacy import displacy
displacy.render(spacy_text, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Отец работает в
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ФСБ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Сегодня срочно вызвали на совещание. Вернулся поздно и ничего не объяснил. Сказал лишь собирать вещи и бежать в магазин за продуктами на две недели. Сейчас едем куда-то далеко за город. Не знаю что происходит, но мне кажется началось...</div></span>

# %%
print(spacy.explain("LOC"))
# Out:
# Non-GPE locations, mountain ranges, bodies of water

# %%
print(spacy.explain("PER"))
# Out:
# Named person or family.

# %%
from spacy import displacy

# %%
displacy.render(spacy_text, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="5d5e283831e44d10b4406deaf80803aa-0" class="displacy" width="7575" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Отец</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">работает</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">в</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">ФСБ.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">Сегодня</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">срочно</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">вызвали</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">на</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">совещание.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Вернулся</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">поздно</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">и</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">ничего</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">не</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">объяснил.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Сказал</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">лишь</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">собирать</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">вещи</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">и</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">бежать</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">в</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">магазин</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">за</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">продуктами</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">на</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">две</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">недели.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">Сейчас</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">едем</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">куда-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="cur
